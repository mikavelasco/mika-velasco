# %% [markdown]
# # Online Business Starter Kit
#
# Welcome to your online business starter kit! Here, we will help you build up your online business from scratch. From inventory making, to a selling system with a digital receipt, we shall guide you throughout this process!
#
# **Disclaimer: Starter kit is only applicable to one inventory. To create more systems for more inventories, you may duplicate this kit!**

# %% [markdown]
# ## 1) Fill up your first inventory
#
# To create your inventory, provide a name for your inventory by filling the blanks guided by the # comments.
#
# Then, run the cell below (Shift + Return/Enter).

# %% [markdown]
# #### "INVENTORY MAKER" CELL:

# %%
# Check # comments before executing

################################################

inventory = {}

# ^ change inventory to the name of your inventory

command = input("Enter (Y) to add item to inventory:   ").upper()

while command == "Y":
    product_code = str(input("Enter product code:  "))
    product_name = str(input("Enter product name:  "))
    product_price = float(input("Enter product price:  "))
    product_quantity = int(input("Enter product quantity:  "))
    
    def enter_product(code, name, price, quantity):
        details = {}
        details["name"] = name
        details["price"] = price
        details["quantity"] = quantity
        entry = {code:details}
        inventory.update(entry)
          # ^ change inventory to the name of your inventory

        
    enter_product(product_code, product_name, product_price, product_quantity)
    command = input("Add another product? Y - Yes and N - End inventory edit:    ")

print("------------------------------------------")
print("Here is your inventory:")
print("Name of inventory: "+"inventory"+"\n")
                             # ^ change inventory to the name of your inventory in between the quotation marks
import pandas as pd

inventorydf = pd.DataFrame.from_dict(inventory, orient='columns')
                                    # ^ change inventory to the name of your inventory
# ^ change inventory to the name of your inventory

print(inventorydf)
        # ^ change inventory to the name of your inventory
# Out:
# Enter (Y) to add item to inventory:   Y
# Enter product code:  apl
# Enter product name:  Apple
# Enter product price:  1
# Enter product quantity:  5
# Add another product? Y - Yes and N - End inventory edit:    Y
# Enter product code:  ban
# Enter product name:  Banana
# Enter product price:  20
# Enter product quantity:  5
# Add another product? Y - Yes and N - End inventory edit:    N
# ------------------------------------------
# Here is your inventory:
# Name of inventory: inventory
#
#             apl     ban
# name      Apple  Banana
# price         1      20
# quantity      5       5

# %% [markdown]
# #### In case you have new products you weren't able to put in your inventory before, you may use the code below!
#
# Please read all the instructions in hashtags before you run the cell!

# %% [markdown]
# #### "ADD TO AN EXISTING INVENTORY" CELL:

# %%
# Check # comments before executing
# if you want to add more to your inventory, you may run this cell 

################################################

command = input("Enter (Y) to add item to inventory:   ")

while command == "Y":
    product_code = str(input("Enter product code:  "))
    product_name = str(input("Enter product name:  "))
    product_price = float(input("Enter product price:  "))
    product_quantity = int(input("Enter product quantity:  "))
    
    def enter_product(code, name, price, quantity):
        details = {}
        details["name"] = name
        details["price"] = price
        details["quantity"] = quantity
        entry = {code:details}
        inventory.update(entry)
        # ^ change inventory to the name of the inventory you want to add to

    enter_product(product_code, product_name, product_price, product_quantity)
    command = input("Add another product? Y - Yes and N - End inventory edit:    ")

print("------------------------------------------")
print("Here is your current inventory:"+"\n")
                            
import pandas as pd

inventorydf = pd.DataFrame.from_dict(inventory, orient='columns')
                                      # ^ change inventory to the name of your inventory  
# ^ change inventory to the name of your inventory

print(inventorydf)
        # ^ change inventory to the name of your inventory
# Out:
# Enter (Y) to add item to inventory:   Y
# Enter product code:  peanuts
# Enter product name:  Peanuts
# Enter product price:  50
# Enter product quantity:  5
# Add another product? Y - Yes and N - End inventory edit:    N
# ------------------------------------------
# Here is your current inventory:
#
#             apl     ban  peanuts
# name      Apple  Banana  Peanuts
# price         1      20       50
# quantity      5       5        5

# %% [markdown]
# #### "RESTOCKING A PRODUCT" CELL:

# %%
# Check # comments before executing
# Run this cell to add stocks to inventory

################################################

restockques = input("Add stocks to a product? (Y/N)  ")

while restockques == "Y":
    restock_code = input("Enter product code:   ")
    restock_quantity = input("Enter number of new stocks:   ")

    inventory[restock_code]["quantity"] = inventory[restock_code]["quantity"] + int(restock_quantity)
                                            # ^ change inventory to the name of your inventory
    # ^ change inventory to the name of your inventory
    
    restockques = input("Add more stocks? (Y/N)  ")
    
if restockques == "N":
    
    print("------------------------------------------")
    print("Here is your current inventory:"+"\n")
                            
    import pandas as pd

    inventorydf = pd.DataFrame.from_dict(inventory, orient='columns')
                                            # ^ change inventory to the name of your inventory
    # ^ change inventory to the name of your inventory
    
    print(inventorydf)
            # ^ change inventory to the name of your inventory

else:
    print("Please input Y or N")
    restockques = input("Add stocks? (Y/N)  ")
# Out:
# Add stocks to a product? (Y/N)  N
# ------------------------------------------
# Here is your current inventory:
#
#             apl     ban  peanuts
# name      Apple  Banana  Peanuts
# price         1      20       50
# quantity      5       5        5

# %% [markdown]
# #### "REPRICING A PRODUCT" CELL:

# %%
# Check # comments before executing
# Run this cell to reprice items

################################################

repriceques = input("Change price of a product? (Y/N)  ")

while repriceques == "Y":
    reprice_code = input("Enter product code:   ")
    new_price = input("Enter new price:   ")

    inventory[reprice_code]["price"] = int(new_price)
    # ^ change inventory to the name of your inventory
    
    repriceques = input("Change more? (Y/N)  ")

if repriceques == "N":
    print("------------------------------------------")
    print("Here is your current inventory:"+"\n")
                            
    import pandas as pd

    inventorydf = pd.DataFrame.from_dict(inventory, orient='columns')
                                            # ^ change inventory to the name of your inventory
    # ^ change inventory to the name of your inventory
    
    print(inventorydf)
            # ^ change inventory to the name of your inventory
    
else:
    print("Please input Y or N")
    repriceques = input("Change price? (Y/N)  ")
# Out:
# Change price of a product? (Y/N)  Y
# Enter product code:   apl
# Enter new price:   10
# Change more? (Y/N)  N
# ------------------------------------------
# Here is your current inventory:
#
#             apl     ban  peanuts
# name      Apple  Banana  Peanuts
# price        10      20       50
# quantity      5       5        5

# %% [markdown]
# #### "RENAMING A PRODUCT" CELL:

# %%
# Check # comments before executing
# Run this cell to rename products

################################################

nameques = input("Change name of a product? (Y/N)  ")

while nameques == "Y":
    name_code = input("Enter product code:   ")
    new_name = input("Enter new name:   ")


    inventory[name_code]["name"] = str(new_name)
    # ^ change inventory to the name of your inventory
    
    nameques = input("Change more? (Y/N)  ")
    
if nameques == "N":

    print("------------------------------------------")
    print("Here is your current inventory:"+"\n")
                            
    import pandas as pd

    inventorydf = pd.DataFrame.from_dict(inventory, orient='columns')
                                            # ^ change inventory to the name of your inventory
    # ^ change inventory to the name of your inventory
    
    print(inventorydf)
            # ^ change inventory to the name of your inventory
    
else:
    print("Please input Y or N")
    nameques = input("Change name? (Y/N)  ")
# Out:
# Change name of a product? (Y/N)  N
# ------------------------------------------
# Here is your current inventory:
#
#             apl     ban  peanuts
# name      Apple  Banana  Peanuts
# price        10      20       50
# quantity      5       5        5

# %% [markdown]
# #### "DELETING A PRODUCT" CELL:

# %%
# Check # comments before executing
# Run this cell to delete item from inventory

################################################

deleteques = input("Delete a product? (Y/N)  ")

while deleteques == "Y":
    delete_code = input('Enter product code:   ')

    inventory.pop(delete_code, None)
    # ^ change inventory to the name of your inventory
    
    deleteques = input("Delete more? (Y/N)  ")


if deleteques == "N":
    print("------------------------------------------")
    print("Here is your current inventory:"+"\n")
                            
    import pandas as pd

    inventorydf = pd.DataFrame.from_dict(inventory, orient='columns')
                                            # ^ change inventory to the name of your inventory
    # ^ change inventory to the name of your inventory
    
    print(inventorydf)
            # ^ change inventory to the name of your inventory

else:
    print("Please input Y or N")
    deleteques = input("Delete product? (Y/N)  ")
# Out:
# Delete a product? (Y/N)  Y
# Enter product code:   peanuts
# Delete more? (Y/N)  N
# ------------------------------------------
# Here is your current inventory:
#
#             apl     ban
# name      Apple  Banana
# price        10      20
# quantity      5       5

# %% [markdown]
# #### "INVENTORY CHECK" CELL

# %%
# Check # comments before executing
# Execute this cell to check the contents of an inventory

################################################

print("Here is your current inventory:"+"\n")
                            
import pandas as pd

inventorydf = pd.DataFrame.from_dict(inventory, orient='columns')
                                        # ^ change inventory to the name of your inventory
# ^ change inventory to the name of your inventory

print(inventorydf)
        # ^ change inventory to the name of your inventory
# Out:
# Here is your current inventory:
#
#             apl     ban
# name      Apple  Banana
# price        10      20
# quantity      5       5

# %% [markdown]
# #### 1.a) Q: "What if I want to create more inventories in the future?"
# ####       A: Just copy the contents or duplicate the "INVENTORY MAKER" CELL and follow the instructions for making and editing an inventory all over again!

# %% [markdown]
# ### -----------------------------------------------------------------------------------------------------
# ### Disclaimer: Steps 2, 3 and Discount Randomizer (optional) apply to only one customer at a time. Duplicate all cells below and paste below the last cell to add new customer
#
# ## 2) Execute your ordering system
#
# To execute your ordering system, you must add the name of your chosen inventory and currency in certain parts of this code (follow # instructions).
#
# Then, run the cell!
#
# **Note that this ordering system will only apply to one inventory. Copy the contents of the cell below/duplicate the cell below if you want to create an ordering system from another inventory**

# %%
# EXECUTE THIS CELL

import pandas as pd

orders = {}

# %%
# Check # comments before executing
# Run this cell to execute your ordering system

################################################

def add_to_cart(cart, ordered_item):
    add_to_cart = cart.append(ordered_item)
    return add_to_cart

cart = []
command = "Y"
while(True):
    command = input("Ordering form. Enter any character to begin. Enter (N) to escape:  ")
    if(command.upper()=="N"):
        break
    else:
        customer_firstname = str(input("Enter your first name: "))
        customer_lastname = str(input("Enter your last name: "))
        
        add = "Y"
        while(add=="Y"):
            ordered_item = dict()
            code = input("Enter product code: ")
            if code in inventory:
                        # ^ change inventory to the name of your inventory
                ordered_item["code"] = code
            else:
                print("CODE DOES NOT EXIST")
                add = input("Add more items? (Y/N): ").upper()
                continue
                
            qty = int(input("Enter quantity: "))
            if qty > inventory[code]["quantity"]:
                        # ^ change inventory to the name of your inventory
                print("INSUFFICIENT STOCKS")
                input("Add more items? (Y/N): ").upper()
                continue
            else:
                ordered_item["qty"] = qty
                inventory[code]["quantity"] = inventory[code]["quantity"] - int(qty)
                                                # ^ change inventory to the name of your inventory
                # ^ change inventory to the name of your inventory
                
            ordered_item["subtotal"] = int(qty) * inventory[code]["price"]
                                                    # ^ change inventory to the name of your inventory
            add_to_cart(cart,ordered_item)
            
            add = input("Add more items? (Y/N): ").upper()
    
    if add == "N":
        
        total_payment = 0
        order_data = {}
        
        for item in cart:
            total_payment += item["subtotal"]
            order_data[inventory[item["code"]]["name"]] = item["qty"]
            
        disccodeques1 = input("Do you have a discount code? (Y/N) ").upper()
        if disccodeques1 == "N":
            finaltotal = total_payment
        elif disccodeques1 == "Y":
            disccodeques2 = input("Please enter discount code: ")
            
            # CALCULATING FOR DISCOUNTED PRICE
            if disccodeques2 in discount_code_list:
                finaltotal = int(int(total_payment) * 0.15) #REPLACE 0.15 WITH HOWEVER MUCH YOU WANT
            else:
                print("Sorry, incorrect code")
                disccodeques3 = input("Try again? (Y/N) ").upper()
                
                if disccodeques3 == "Y":
                    disccodeques2 = input("Please enter discount code: ")
                elif disccodeques3 == "N":
                    finaltotal = total_payment
                else:
                    print("Please enter Y or N")
                    disccodeques3 = input("Try again? (Y/N) ").upper()        
        else:
            print("Please enter Y or N")
            disccodeques1 = input("Do you have a discount code? (Y/N) ").upper()
        
        
        amountpaid = int(input("Please enter amount paid: "))
        if amountpaid < finaltotal:
            print("INSUFFICIENT AMOUNT. PLEASE RESTART ORDER FORM. ITEMS WILL BE RETURNED TO INVENTORY")
            print("\n")
            
            ordercancel = {x["code"]: x for x in cart}
            for x in ordercancel.keys():
                if x in inventory.keys():
                    
                        # ^ change inventory to the name of your inventory
                        
                    inventory[x]["quantity"] = inventory[x]["quantity"] + ordercancel[x]["qty"]
                                                # ^ change inventory to the name of your inventory
                    # ^ change inventory to the name of your inventory
                    
            ordercancel = []
            cart = []
            continue  
        else:
            change = amountpaid - int(finaltotal)
                    
                
        ## RECEIPT ##              
        
            print()
            print("\n")
            print("- START OF OFFICIAL RECEIPT -")
            print("\n")
            print("-----------------------------------------------------")
            print("                 Official Receipt                    ")
            print()
            print("Product","\t","  Quantity","\t","  Subtotal")
            for item in cart:
                
                print(inventory[item["code"]]["name"],"\t","\t",item["qty"],"\t","\t","P",item["subtotal"])
                                                                                    # ^ change to currency of your choice
                        # ^ change inventory to the name of your inventory 
            print("\n")    
            if disccodeques1 == "N":
                print("Discount: N")
            else:
                print("Discount: Y")
            print("Your total is: ","P",finaltotal)
                                    # ^ change to currency of your choice

            print("Amount paid is: ","P",amountpaid)
                                    # ^ change to currency of your choice
            
            print("Change: ","P",change)
                            # ^ change to currency of your choice
                
            import datetime
            print(datetime.datetime.now())
            
            print("-----------------------------------------------------")
            print("Please proceed to the next window for your payment and shipping.")
            print("\n - END OF OFFICIAL RECEIPT -  \n")
            
            cart = [] 

    else:
        print("Please Enter Y or N")
        add = input("Add more items? (Y/N): ").upper()
# Out:
# Ordering form. Enter any character to begin. Enter (N) to escape:  hi
# Enter your first name: Juan
# Enter your last name: Cruz
# Enter product code: apl
# Enter quantity: 1
# Add more items? (Y/N): Y
# Enter product code: ban
# Enter quantity: 1
# Add more items? (Y/N): N
# Do you have a discount code? (Y/N) N
# Please enter amount paid: 100
#
#
#
# - START OF OFFICIAL RECEIPT -
#
#
# -----------------------------------------------------
#                  Official Receipt
#
# Product 	   Quantity 	   Subtotal
# Apple 	 	 1 	 	 P 10
# Banana 	 	 1 	 	 P 20.0
#
#
# Discount: N
# Your total is:  P 30.0
# Amount paid is:  P 100
# Change:  P 70
# 2020-08-13 17:00:09.166366
# -----------------------------------------------------
# Please proceed to the next window for your payment and shipping.
#
#  - END OF OFFICIAL RECEIPT -
#
# Ordering form. Enter any character to begin. Enter (N) to escape:  N

# %% [markdown]
# ## 3) Execute the payment and shipping system
#
# To execute your payment and shipping system, you must add the name of your chosen currency in certain parts of this code (follow # instructions).
#
# Then, run the cell!

# %%
# Check # comments before executing
# Run this cell to execute your payment and shipping system

################################################


print("                   Shipping Method                   ")
print("Methods:\nA. Shipping \nB. Pick-up")
shipping_method = (input("Please enter your preferred method for receiving your items (A/B):  ")).upper()
if shipping_method == "B":
    ship = "Pick-up selected"
elif shipping_method=="A": 
    print("Please enter shipping details (press Enter on unapplicable items): ")
    delfirstname = str(input("First name of person receiving order: "))
    dellastname = str(input("Last name of person receiving order: "))
    delnom = str(input("Street number: "))
    delstreet = str(input("Street name: "))
    delsubdiv = str(input("Subdivision: "))
    delbarangay = str(input("Barangay: "))
    delcity = str(input("City or Province: "))
    delarea = str(input("Region: "))
    delcode = str(input("Postal Code: "))
    ship = str("Shipping selected. Deliver to {} {} {}, {}. {}".format(delnom,delstreet,delcity,delarea,delcode)) 


                   
print("                   Payment Method                    ")
print("Methods:\nA. Cash on Delivery \nB. Cash Deposit \nC. Card")
payment_method = (input("Please enter your preferred method of payment (A/B/C):  ")).upper()

if payment_method=="A":
    givenpayment = float(input("Please enter the amount you are paying:  "))
    while givenpayment == finaltotal:
        lastpayment = "COD. Exact amount."
        
        print("\n")    
        print("-----------------------------------------------------")
        print("                Payment and Shipping                 \n")
        print("Here is your total amount: P {}\n".format(finaltotal))
                                        # ^ change to currency of your choice
        print("Shipping method: {}\n".format(ship))
        print("Payment method: {}\n".format(lastpayment))
        print("-----------------------------------------------------")


        print("Thank you for shopping with us! Have a great day.")
        
        break
        
    while givenpayment > finaltotal:
        check_for_change = givenpayment-finaltotal
        lastpayment = "COD. Your change is: {}".format(check_for_change)
        
        print("\n")    
        print("-----------------------------------------------------")
        print("                Payment and Shipping                 \n")
        print("Here is your total amount: P {}\n".format(finaltotal))
                                        # ^ change to currency of your choice
        print("Shipping method: {}\n".format(ship))
        print("Payment method: {}\n".format(lastpayment))
        print("-----------------------------------------------------")
        
        print("Thank you for shopping with us! Have a great day.")

        break 
        
    if givenpayment < int(finaltotal):
        print("INSUFFICIENT PAYMENT. PLEASE RETRY.")
        givenpayment = float(input("Please enter the amount you are paying:  "))
                       
    
elif payment_method=="B":
    deposit_account = str(input("Through which bank? (BDO/BPI):  "))
    bank_name = "Adam Smith"
                # ^ you may change this in between "" to whoever is receiving the payment
    bank_type = "BDO"
                 # ^ you may change this in between "" to the bank type of the account
    bank_number = "123 456 7890"
                    # ^ you may change this in between "" to the bank account number
    bank_details = "Here are our bank details: {} {} {}".format(bank_name, bank_type, bank_number)
    lastpayment = "Deposit through {}. Please provide us with your deposit slip via this email: 123@gmail.com ".format(deposit_account)
                                                                                                # ^ add your business' email
    print("\n")    
    print("-----------------------------------------------------")
    print("                Payment and Shipping                 \n")
    print("Here is your total amount: P {}\n".format(finaltotal))
                                # ^ change to currency of your choice

    print("Shipping method: {}\n".format(ship))
    print(bank_details)
    print("Payment method: {}\n".format(lastpayment))
    print("-----------------------------------------------------")


    print("Thank you for shopping with us! Have a great day.")
    
elif payment_method=="C":
    card_type = str(input("Type of card (ex. Mastercard, etc.):  "))
    card_name = str(input("Please enter the name on your credit card:  "))
    card_number = str(input("Please enter your credit card number:  "))
    card_expiration = str(input("Please enter your credit card expiration date (MM/YY):  "))
    card_cvv = str(input("Please enter the 3-digit CVV: "))
    lastpayment = "Paid with credit card."
    
    print("\n")    
    print("-----------------------------------------------------")
    print("                Payment and Shipping                 \n")
    print("Here is your total amount: P {}\n".format(finaltotal))
                                # ^ change to currency of your choice

    print("Shipping method: {}\n".format(ship))
    print("Payment method: {}\n".format(lastpayment))
    print("-----------------------------------------------------")


    print("Thank you for shopping with us! Have a great day.")
# Out:
#                    Shipping Method
# Methods:
# A. Shipping
# B. Pick-up
# Please enter your preferred method for receiving your items (A/B):  A
# Please enter shipping details (put N/A on unapplicable items):
# First name of person receiving order: Juan
# Last name of person receiving order: Cruz
# Street number: 77
# Street name: ITM
# Subdivision: Valle Verde 1
# Barangay: Ugong
# City or Province: Manila
# Region: NCR
# Postal Code: 1000
#                    Payment Method
# Methods:
# A. Cash on Delivery
# B. Cash Deposit
# C. Card
# Please enter your preferred method of payment (A/B/C):  B
# Through which bank? (BDO/BPI):  BDO
#
#
# -----------------------------------------------------
#                 Payment and Shipping
#
# Here is your total amount: P 30.0
#
# Shipping method: Shipping selected. Deliver to 77 ITM Manila, NCR. 1000
#
# Here are our bank details: Adam Smith BDO 123 456 7890
# Payment method: Deposit through BDO. Please provide us with your deposit slip via this email: 123@gmail.com
#
# -----------------------------------------------------
# Thank you for shopping with us! Have a great day.

# %%
# EXECUTE THIS CELL BEFORE PROCEEDING TO NEXT CELL

indiv_order = {}


indiv_order["Name"] = "{} {}".format(customer_firstname,customer_lastname)
indiv_order["Order Information"] = (order_data)
indiv_order["Total Due"] = finaltotal
indiv_order["Amount Paid"] = amountpaid
indiv_order["Change for Payment"] = change
indiv_order["Shipping Method"] = ship
if "delfirstname" and "dellastname" in locals():
    indiv_order["Order Recipient"] = "{} {}".format(delfirstname,dellastname)
    indiv_order["Shipping Address"] = "{} {} {} {} {} {} {}".format(delnom,delstreet,delsubdiv,delbarangay,delcity,delarea,delcode)
else:
    pass
indiv_order["Payment Method"] = lastpayment
if "deposit_account" in locals():
    indiv_order["Cash Deposit Bank"] = deposit_account
else:
    pass
if "card_type" in locals():
    indiv_order["Card Type"] = card_type
    indiv_order["Card Name"] = card_name
    indiv_order["Card Number"] = card_number
    indiv_order["Card Expiration Date"] = card_expiration
    indiv_order["Card CVV"] = card_cvv
else:
    pass

orders[customer_lastname] = indiv_order

# %%
# EXECUTE THIS CELL TO SEE YOUR CURRENT ORDERS

official_orders = pd.DataFrame(orders)
official_orders = official_orders.reindex(["Name","Order Information","Total Due","Amount Paid","Change for Payment",
                                           "Shipping Method","Order Recipient","Shipping Address","Payment Method",
                                           "Cash Deposit Bank","Card Type","Card Name","Card Number",
                                           "Card Expiration Date","Card CVV"])
official_orders
# Out:
#                                                                    Cruz
# Name                                                          Juan Cruz
# Order Information                             {'Apple': 1, 'Banana': 1}
# Total Due                                                            30
# Amount Paid                                                         100
# Change for Payment                                                   70
# Shipping Method       Shipping selected. Deliver to 77 ITM Manila, N...
# Order Recipient                                               Juan Cruz
# Shipping Address             77 ITM Valle Verde 1 Ugong Manila NCR 1000
# Payment Method        Deposit through BDO. Please provide us with yo...
# Cash Deposit Bank                                                   BDO
# Card Type                                                           NaN
# Card Name                                                           NaN
# Card Number                                                         NaN
# Card Expiration Date                                                NaN
# Card CVV                                                            NaN

# %%
# EXECUTE THIS CELL IF YOU WANT AN EXCEL SHEET OF YOUR ORDERS

official_orders.to_excel("official_orders.xlsx")
                        # ^ you may change the name of the excel sheet

# %% [markdown]
# ### The Discount Randomizer
#
# Want to give your customers a little bonus treat for spending more than ____ pesos in one purchase from your shop?
#
# Use this discount randomizer program for your customers to use!
#
# Note: run all the cells to test!

# %%
import numpy as np
import random
import string
discount_code_list = []

# %%
print("___________________________________________________________________________________________")
print("                                     Discount Giveaway                                     ")
print("Congrats! You have been given a chance to receive a 15% off discount on your next purchase.")
print("                    If you get the magic number of 5, you win the discount!                ")
print("___________________________________________________________________________________________")

start_randomizer = input("Type GO to start randomizing!  ")

magic_number = np.random.randint(1,10)

print("Your magic number is: ",magic_number)

def get_discount_code(length):
    letters = string.ascii_letters
    result = ''.join(random.choice(letters) for i in range(length))
    return result

discount_code = get_discount_code(8)

if magic_number == 5:
    print("Congratulations! Here is your discount code: ", discount_code)
    discount_code_list.append(discount_code)
    print("Please take note of your discount code so you can make use of it on your next purchase!")
else:
    print("Try again on your next purchase!")
# Out:
# ___________________________________________________________________________________________
#                                      Discount Giveaway
# Congrats! You have been given a chance to receive a 15% off discount on your next purchase.
#                     If you get the magic number of 5, you win the discount!
# ___________________________________________________________________________________________
# Type GO to start randomizing!  GO
# Your magic number is:  5
# Congratulations! Here is your discount code:  XdnyWNvZ
# Please take note of your discount code so you can make use of it on your next purchase!

# %%
# CHECK OUT YOUR LIST OF DISCOUNT CODES!

discount_code_list
# Out:
# ['XdnyWNvZ']
